# %%
import os

repo_path = os.getcwd()
print(repo_path)

# %%
import pandas as pd

customers = pd.read_csv(
    "/Workspace/Users/208r1a04j1@gmail.com/ecommerce-data-engineering/datasets/customers.csv"
)

customers.head()

# %%
repo_root = "/Workspace/Users/208r1a04j1@gmail.com/ecommerce-data-engineering"

# %%
customers_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(f"{repo_root}/datasets/customers.csv")
)

products_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(f"{repo_root}/datasets/products.csv")
)

orders_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(f"{repo_root}/datasets/orders.csv")
)

# %%
# %sql
SELECT current_catalog();

# %%
# %sql
SELECT current_schema();

# %%
customers_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze_customers")

products_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze_products")

orders_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze_orders")

# %%
# %sql
show tables

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;
